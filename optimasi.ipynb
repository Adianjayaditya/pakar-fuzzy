# %%
import numpy as np

# %%
# %run fuzzy_pakar_csv.ipynb
# Out:
# waktu belajar   : {'kecil': 0, 'sedang': 0.136986301369863, 'besar': 0.863013698630137}
# lama jawab soal : {'kecil': 0, 'sedang': 0, 'besar': 1}
# nilai           : {'kecil': 0, 'sedang': 0, 'besar': 1}
# RULE 1: IF waktu_belajar kecil (0.0000) AND lama_jawab_soal kecil (0.0000) AND nilai kecil (0.0000) THEN kelulusan tidak lulus : ALPAPREDIKAT = 0.0000
# RULE 2: IF waktu_belajar kecil (0.0000) AND lama_jawab_soal kecil (0.0000) AND nilai kecil (0.0000) THEN kelulusan tidak lulus : ALPAPREDIKAT = 0.0000
# RULE 3: IF waktu_belajar kecil (0.0000) AND lama_jawab_soal kecil (0.0000) AND nilai kecil (1.0000) THEN kelulusan tidak lulus : ALPAPREDIKAT = 0.0000
# RULE 4: IF waktu_belajar kecil (0.0000) AND lama_jawab_soal sedang (0.0000) AND nilai sedang (0.0000) THEN kelulusan tidak lulus : ALPAPREDIKAT = 0.0000
# RULE 5: IF waktu_belajar kecil (0.0000) AND lama_jawab_soal sedang (0.0000) AND nilai sedang (0.0000) THEN kelulusan tidak lulus : ALPAPREDIKAT = 0.0000
# RULE 6: IF waktu_belajar kecil (0.0000) AND lama_jawab_soal sedang (0.0000) AND nilai sedang (1.0000) THEN kelulusan tidak lulus : ALPAPREDIKAT = 0.0000
# RULE 7: IF waktu_belajar kecil (0.0000) AND lama_jawab_soal besar (1.0000) AND nilai besar (0.0000) THEN kelulusan tidak lulus : ALPAPREDIKAT = 0.0000
# RULE 8: IF waktu_belajar kecil (0.0000) AND lama_jawab_soal besar (1.0000) AND nilai besar (0.0000) THEN kelulusan tidak lulus : ALPAPREDIKAT = 0.0000
# RULE 9: IF waktu_belajar kecil (0.0000) AND lama_jawab_soal besar (1.0000) AND nilai besar (1.0000) THEN kelulusan lulus : ALPAPREDIKAT = 0.0000
# RULE 10: IF waktu_belajar sedang (0.1370) AND lama_jawab_soal kecil (0.0000) AND nilai kecil (0.0000) THEN kelulusan tidak lulus : ALPAPREDIKAT = 0.0000
# RULE 11: IF waktu_belajar sedang (0.1370) AND lama_jawab_soal kecil (0.0000) AND nilai kecil (0.0000) THEN kelulusan tidak lulus : ALPAPREDIKAT = 0.0000
# RULE 12: IF waktu_belajar sedang (0.1370) AND lama_jawab_soal kecil (0.0000) AND nilai kecil (1.0000) THEN kelulusan tidak lulus : ALPAPREDIKAT = 0.0000
# RULE 13: IF waktu_belajar sedang (0.1370) AND lama_jawab_soal sedang (0.0000) AND nilai sedang (0.0000) THEN kelulusan tidak lulus : ALPAPREDIKAT = 0.0000
# RULE 14: IF waktu_belajar sedang (0.1370) AND lama_jawab_soal sedang (0.0000) AND nilai sedang (0.0000) THEN kelulusan lulus : ALPAPREDIKAT = 0.0000
# RULE 15: IF waktu_belajar sedang (0.1370) AND lama_jawab_soal sedang (0.0000) AND nilai sedang (1.0000) THEN kelulusan lulus : ALPAPREDIKAT = 0.0000
# RULE 16: IF waktu_belajar sedang (0.1370) AND lama_jawab_soal besar (1.0000) AND nilai besar (0.0000) THEN kelulusan tidak lulus : ALPAPREDIKAT = 0.0000
# RULE 17: IF waktu_belajar sedang (0.1370) AND lama_jawab_soal besar (1.0000) AND nilai besar (0.0000) THEN kelulusan lulus : ALPAPREDIKAT = 0.0000
# RULE 18: IF waktu_belajar sedang (0.1370) AND lama_jawab_soal besar (1.0000) AND nilai besar (1.0000) THEN kelulusan lulus : ALPAPREDIKAT = 0.1370
# RULE 19: IF waktu_belajar besar (0.8630) AND lama_jawab_soal kecil (0.0000) AND nilai kecil (0.0000) THEN kelulusan tidak lulus : ALPAPREDIKAT = 0.0000
# RULE 20: IF waktu_belajar besar (0.8630) AND lama_jawab_soal kecil (0.0000) AND nilai kecil (0.0000) THEN kelulusan tidak lulus : ALPAPREDIKAT = 0.0000
# RULE 21: IF waktu_belajar besar (0.8630) AND lama_jawab_soal kecil (0.0000) AND nilai kecil (1.0000) THEN kelulusan tidak lulus : ALPAPREDIKAT = 0.0000
# RULE 22: IF waktu_belajar besar (0.8630) AND lama_jawab_soal sedang (0.0000) AND nilai sedang (0.0000) THEN kelulusan lulus : ALPAPREDIKAT = 0.0000
# RULE 23: IF waktu_belajar besar (0.8630) AND lama_jawab_soal sedang (0.0000) AND nilai sedang (0.0000) THEN kelulusan lulus : ALPAPREDIKAT = 0.0000
# RULE 24: IF waktu_belajar besar (0.8630) AND lama_jawab_soal sedang (0.0000) AND nilai sedang (1.0000) THEN kelulusan lulus : ALPAPREDIKAT = 0.0000
# RULE 25: IF waktu_belajar besar (0.8630) AND lama_jawab_soal besar (1.0000) AND nilai besar (0.0000) THEN kelulusan lulus : ALPAPREDIKAT = 0.0000
# RULE 26: IF waktu_belajar besar (0.8630) AND lama_jawab_soal besar (1.0000) AND nilai besar (0.0000) THEN kelulusan lulus : ALPAPREDIKAT = 0.0000
# RULE 27: IF waktu_belajar besar (0.8630) AND lama_jawab_soal besar (1.0000) AND nilai besar (1.0000) THEN kelulusan lulus : ALPAPREDIKAT = 0.8630
# {'rule': 1, 'kepercayaan_pakar': 'kecil', 'alpapredikat': 0}
# {'rule': 2, 'kepercayaan_pakar': 'kecil', 'alpapredikat': 0}
# {'rule': 3, 'kepercayaan_pakar': 'kecil', 'alpapredikat': 0}
# {'rule': 4, 'kepercayaan_pakar': 'kecil', 'alpapredikat': 0}
# {'rule': 5, 'kepercayaan_pakar': 'kecil', 'alpapredikat': 0}
# {'rule': 6, 'kepercayaan_pakar': 'kecil', 'alpapredikat': 0}
# {'rule': 7, 'kepercayaan_pakar': 'kecil', 'alpapredikat': 0}
# {'rule': 8, 'kepercayaan_pakar': 'kecil', 'alpapredikat': 0}
# {'rule': 9, 'kepercayaan_pakar': 'besar', 'alpapredikat': 0}
# {'rule': 10, 'kepercayaan_pakar': 'kecil', 'alpapredikat': 0}
# {'rule': 11, 'kepercayaan_pakar': 'kecil', 'alpapredikat': 0}
# {'rule': 12, 'kepercayaan_pakar': 'kecil', 'alpapredikat': 0}
# {'rule': 13, 'kepercayaan_pakar': 'kecil', 'alpapredikat': 0}
# {'rule': 14, 'kepercayaan_pakar': 'besar', 'alpapredikat': 0}
# {'rule': 15, 'kepercayaan_pakar': 'besar', 'alpapredikat': 0}
# {'rule': 16, 'kepercayaan_pakar': 'sedang', 'alpapredikat': 0}
# {'rule': 17, 'kepercayaan_pakar': 'besar', 'alpapredikat': 0}
# {'rule': 18, 'kepercayaan_pakar': 'besar', 'alpapredikat': 0.136986301369863}
# {'rule': 19, 'kepercayaan_pakar': 'kecil', 'alpapredikat': 0}
# {'rule': 20, 'kepercayaan_pakar': 'kecil', 'alpapredikat': 0}
# {'rule': 21, 'kepercayaan_pakar': 'sedang', 'alpapredikat': 0}
# {'rule': 22, 'kepercayaan_pakar': 'sedang', 'alpapredikat': 0}
# {'rule': 23, 'kepercayaan_pakar': 'besar', 'alpapredikat': 0}
# {'rule': 24, 'kepercayaan_pakar': 'besar', 'alpapredikat': 0}
# {'rule': 25, 'kepercayaan_pakar': 'besar', 'alpapredikat': 0}
# {'rule': 26, 'kepercayaan_pakar': 'besar', 'alpapredikat': 0}
# {'rule': 27, 'kepercayaan_pakar': 'besar', 'alpapredikat': 0.863013698630137}
# Hasil Defuzzifikasi:  87.5
# waktu belajar   : {'kecil': 0, 'sedang': 0, 'besar': 1}
# lama jawab soal : {'kecil': 0.6653543307086615, 'sedang': 0.3346456692913386, 'besar': 0}
# nilai           : {'kecil': 0.49079754601227005, 'sedang': 0.50920245398773, 'besar': 0}
# Aktual: 1, Prediksi: 0      :   SALAH
# waktu belajar   : {'kecil': 0, 'sedang': 0.0821917808219178, 'besar': 0.9178082191780822}
# lama jawab soal : {'kecil': 0, 'sedang': 0.6114942528735632, 'besar': 0.38850574712643676}
# nilai           : {'kecil': 0.3680981595092025, 'sedang': 0.6319018404907975, 'besar': 0}
# Aktual: 1, Prediksi: 0      :   SALAH
# waktu belajar   : {'kecil': 0, 'sedang': 0, 'besar': 1}
# lama jawab soal : {'kecil': 0, 'sedang': 0, 'besar': 1}
# nilai           : {'kecil': 0.3202453987730061, 'sedang': 0.6797546012269938, 'besar': 0}
# Aktual: 1, Prediksi: 1      :   B
# waktu belajar   : {'kecil': 0.3979591836734694, 'sedang': 0.6020408163265306, 'besar': 0}
# lama jawab soal : {'kecil': 0, 'sedang': 0, 'besar': 1}
# nilai           : {'kecil': 0.3202453987730061, 'sedang': 0.6797546012269938, 'besar': 0}
# Aktual: 1, Prediksi: 0      :   SALAH
# waktu belajar   : {'kecil': 0, 'sedang': 0, 'besar': 1}
# lama jawab soal : {'kecil': 0, 'sedang': 0, 'besar': 1}
# nilai           : {'kecil': 0.3202453987730061, 'sedang': 0.6797546012269938, 'besar': 0}
# Aktual: 1, Prediksi: 1      :   B
# waktu belajar   : {'kecil': 0, 'sedang': 0.3424657534246575, 'besar': 0.6575342465753424}
# lama jawab soal : {'kecil': 0, 'sedang': 0, 'besar': 1}
# nilai           : {'kecil': 0.3202453987730061, 'sedang': 0.6797546012269938, 'besar': 0}
# Aktual: 1, Prediksi: 1      :   B
# waktu belajar   : {'kecil': 0.01020408163265306, 'sedang': 0.9897959183673469, 'besar': 0}
# lama jawab soal : {'kecil': 0, 'sedang': 0.06666666666666667, 'besar': 0.9333333333333333}
# nilai           : {'kecil': 0, 'sedang': 0.9805882352941178, 'besar': 0.019411764705882253}
# Aktual: 1, Prediksi: 1      :   B
# waktu belajar   : {'kecil': 0, 'sedang': 1, 'besar': 0}
# lama jawab soal : {'kecil': 0, 'sedang': 0.6988505747126437, 'besar': 0.30114942528735633}
# nilai           : {'kecil': 0, 'sedang': 0.9805882352941178, 'besar': 0.019411764705882253}
# Aktual: 1, Prediksi: 1      :   B
# waktu belajar   : {'kecil': 0, 'sedang': 0, 'besar': 1}
# lama jawab soal : {'kecil': 0, 'sedang': 0, 'besar': 1}
# nilai           : {'kecil': 0, 'sedang': 0.9805882352941178, 'besar': 0.019411764705882253}
# Aktual: 1, Prediksi: 1      :   B
# waktu belajar   : {'kecil': 0, 'sedang': 0

# lama jawab soal : {'kecil': 0, 'sedang': 0, 'besar': 1}
# nilai           : {'kecil': 0, 'sedang': 0.29411764705882354, 'besar': 0.7058823529411765}
# Aktual: 0, Prediksi: 1      :   SALAH
# waktu belajar   : {'kecil': 1, 'sedang': 0, 'besar': 0}
# lama jawab soal : {'kecil': 1, 'sedang': 0, 'besar': 0}
# nilai           : {'kecil': 0, 'sedang': 0, 'besar': 1}
# Aktual: 0, Prediksi: 0      :   B
# waktu belajar   : {'kecil': 0, 'sedang': 0.9863013698630136, 'besar': 0.0136986301369863}
# lama jawab soal : {'kecil': 1, 'sedang': 0, 'besar': 0}
# nilai           : {'kecil': 0, 'sedang': 0, 'besar': 1}
# Aktual: 0, Prediksi: 0      :   B
# waktu belajar   : {'kecil': 0.7959183673469388, 'sedang': 0.20408163265306123, 'besar': 0}
# lama jawab soal : {'kecil': 1, 'sedang': 0, 'besar': 0}
# nilai           : {'kecil': 0, 'sedang': 0, 'besar': 1}
# Aktual: 0, Prediksi: 0      :   B
# waktu belajar   : {'kecil': 1, 'sedang': 0, 'besar': 0}
# lama jawab soal : {'kecil': 1, 'sedang': 0, 'besar': 0}
# nilai           : {'kecil': 0, 'sedang': 0, 'besar': 1}
# Aktual: 0, Prediksi: 0      :   B
# waktu belajar   : {'kecil': 1, 'sedang': 0, 'besar': 0}
# lama jawab soal : {'kecil': 1, 'sedang': 0, 'besar': 0}
# nilai           : {'kecil': 0, 'sedang': 0, 'besar': 1}
# Aktual: 0, Prediksi: 0      :   B
# waktu belajar   : {'kecil': 1, 'sedang': 0, 'besar': 0}
# lama jawab soal : {'kecil': 1, 'sedang': 0, 'besar': 0}
# nilai           : {'kecil': 0, 'sedang': 0, 'besar': 1}
# Aktual: 0, Prediksi: 0      :   B
#
# AKURASI: 78.5047%

# %%
class Particle:
    def __init__(self, bounds):
        self.bounds = bounds
        self.position = self._generate_position()
        self.velocity = self._generate_velocity()
        self.best_position = np.copy(self.position)
        self.best_score = -float('inf')

    def _generate_position(self):
        position = []
        for min_bound, max_bound, length in self.bounds:
            segment = np.random.uniform(min_bound, max_bound, size=length)
            position.extend(segment)
        return np.array(position)

    def _generate_velocity(self):   
        velocity = []
        for _, _, length in self.bounds:
            segment = np.random.uniform(-1, 1, size=length)
            velocity.extend(segment)
        return np.array(velocity)

    def update_velocity(self, global_best_position, w, c1, c2):
        r1 = np.random.rand(len(self.position))
        r2 = np.random.rand(len(self.position))
        cognitive = c1 * r1 * (self.best_position - self.position)
        social = c2 * r2 * (global_best_position - self.position)
        self.velocity = w * self.velocity + cognitive + social

    def update_position(self):
        self.position += self.velocity
        start_idx = 0
        for min_bound, max_bound, length in self.bounds:
            end_idx = start_idx + length
            self.position[start_idx:end_idx] = np.clip(
                self.position[start_idx:end_idx], min_bound, max_bound
            )
            start_idx = end_idx

def objective_function(particle_position, dataset):
    prediksi_benar = 0
    for i in range(len(dataset)):
        waktu_belajar = dataset.loc[i, 'rerata_durasi_akses_materi']
        lama_jawab_soal = dataset.loc[i, 'durasi_berlatih']
        nilai = dataset.loc[i, 'nilai']
        aktual_kelulusan = dataset.loc[i, 'kelulusan']
        x, y, z = func_fuzzifikasi(waktu_belajar, lama_jawab_soal, nilai, particle_position)
        hasil_inferensi, rule_text = inferensi_mamdani(x, y, z, rules)
        hasil_agregasi = agregasi(hasil_inferensi)
        hasil_defuzzifikasi = defuzzifikasi(hasil_agregasi)
        prediksi_kelulusan = kelulusan(hasil_defuzzifikasi)
        if int(prediksi_kelulusan) == int(aktual_kelulusan):
            prediksi_benar += 1
        else:
            continue
    akurasi = (prediksi_benar / len(dataset)) * 100
    return akurasi

def particle_swarm_optimization(bounds, dataset, num_particles, max_iter, w=0.5, c1=2, c2=2):
    swarm = []
    for _ in range(num_particles):
        swarm.append(Particle(bounds))
    global_best_position = None
    global_best_score = -float('inf')

    for iteration in range(max_iter):
        for particle in swarm:
            # Evaluate fitness
            print(particle.position)
            # print(len(particle.velocity))
            particle_score = objective_function(particle.position, dataset)
            # print(particle_score)
            if particle_score > particle.best_score:
                particle.best_score = particle_score
                particle.best_position = np.copy(particle.position)

            if particle_score > global_best_score:
                global_best_score = particle_score
                global_best_position = np.copy(particle.position)

        # Update velocity and position
        for particle in swarm:
            particle.update_velocity(global_best_position, w, c1, c2)
            particle.update_position(bounds)

        print(f"Iteration {iteration+1}/{max_iter}, Best Score: {global_best_score}")

    return global_best_position, global_best_score


bounds = [
    (0, 3600, 11),  # Elemen 0-10 dengan batas [0, 1]
    (0, 9000, 11),  # Elemen 11-20 dengan batas [1, 5]
    (0, 100, 10)  # Elemen 21-31 dengan batas [-3, 3]
]

# Run PSO
num_particles = 10
max_iter = 20
best_params, best_score = particle_swarm_optimization(bounds, dataset, num_particles, max_iter)

print("\nOptimal Parameters:")
print(f"C: {best_params[0]:.4f}, Gamma: {best_params[1]:.4f}")
print(f"Best Cross-Validation Accuracy: {best_score:.4f}")
# Out:
# [1760.3468122  2546.50249587 1790.30289991   29.30443706  573.91090189
#  2115.31532884 3012.5755997  3272.5503367  3565.34896141 2963.70104247
#  2077.50572272  928.93261758  671.11889381 7645.16642348 5672.55958304
#   747.094632   3396.66992033 4760.20836968 7888.5650653  3176.45174988
#  4925.88787034 4479.89136948   62.60230147   78.2000505    77.45676435
#    67.84154074   97.91990633   71.89343521   52.04749217   11.22329403
#     8.52121358   62.75138947]
# waktu belajar   : {'kecil': 0, 'sedang': 0.010437947256959772, 'besar': 0}
# lama jawab soal : {'kecil': 0, 'sedang': 0, 'besar': 0}
# nilai           : {'kecil': 0, 'sedang': 0, 'besar': 0}
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[248], line 100
#      98 num_particles = 10
#      99 max_iter = 20
# --> 100 best_params, best_score = particle_swarm_optimization(bounds, dataset, num_particles, max_iter)
#     102 print("\nOptimal Parameters:")
#     103 print(f"C: {best_params[0]:.4f}, Gamma: {best_params[1]:.4f}")
#
# Cell In[248], line 71, in particle_swarm_optimization(bounds, dataset, num_particles, max_iter, w, c1, c2)
#      69 print(particle.position)
#      70 # print(len(particle.velocity))
# ---> 71 particle_score = objective_function(particle.position, dataset)
#      72 # print(particle_score)
#      73 if particle_score > particle.best_score:
#
# Cell In[248], line 50, in objective_function(particle_position, dataset)
#      48 hasil_inferensi, rule_text = inferensi_mamdani(x, y, z, rules)
#      49 hasil_agregasi = agregasi(hasil_inferensi)
# ---> 50 hasil_defuzzifikasi = defuzzifikasi(hasil_agregasi)
#      51 prediksi_kelulusan = kelulusan(hasil_defuzzifikasi)
#      52 if int(prediksi_kelulusan) == int(aktual_kelulusan):
#
# File ~\AppData\Local\Temp\ipykernel_14300\2000983416.py:16, in defuzzifikasi(agregasi_kelulusan)
#      14 total_momen = momen_kecil + momen_sedang + momen_besar
#      15 total_luas = luas_kecil + luas_sedang + luas_besar
# ---> 16 COA = total_momen / total_luas
#      17 return COA
#
# ZeroDivisionError: float division by zero

# %%
def objective_function(particle_position, dataset):
    prediksi_benar = 0
    for i in range(len(dataset)):
        waktu_belajar = dataset.loc[i, 'rerata_durasi_akses_materi']
        lama_jawab_soal = dataset.loc[i, 'durasi_berlatih']
        nilai = dataset.loc[i, 'nilai']
        aktual_kelulusan = dataset.loc[i, 'kelulusan']
        x, y, z = func_fuzzifikasi(waktu_belajar, lama_jawab_soal, nilai, particle_position)
        hasil_inferensi, rule_text = inferensi_mamdani(x, y, z, rules)
        hasil_agregasi = agregasi(hasil_inferensi)
        hasil_defuzzifikasi = defuzzifikasi(hasil_agregasi)
        prediksi_kelulusan = kelulusan(hasil_defuzzifikasi)
        if int(prediksi_kelulusan) == int(aktual_kelulusan):
            prediksi_benar += 1
        else:
            continue
    akurasi = (prediksi_benar / len(dataset)) * 100
    return akurasi

# %%
hasil = objective_function(particle_position123, dataset)
hasil
# Out:
# 78.50467289719626
